# %%
import pandas as pd
import numpy as np
import pickle as pkl

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(True)

from xgboost import XGBClassifier, XGBRegressor
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, KFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv('df_after_engineering.csv')
df.shape
# Out:
# (891, 21)

# %%
import warnings
warnings.filterwarnings('ignore')

data = df.drop('PassengerId', axis=1)
#data = data.dropna(subset=['TransformedCabinDeck'])
#data = data.drop('TransformedCabinDeck', axis=1)
#display(data)

## TESTING
# data = data.where(data['Sex'] == 0).dropna(subset=['Sex'])
# data = data.where(data['Pclass'] == 0).dropna(subset=['Pclass'])
print(data.shape)

X_total = data.drop('Survived', axis=1)
# seems like gb trees are extremely robust to poor features so I won't bother dropping anything
y_total = data['Survived']

# lets keep a validation set as a sanity check
training_acc_list = []
valid_acc_list = []

poor_women_acc_list = []
middle_women_acc_list = []
rich_women_acc_list = []

men_acc_list = []
n_trials = 30 

steps=1
param_dict = {
    'learning_rate' : np.linspace(0.1, 0.75, steps),
    'gamma' : np.linspace(1, 4.5, steps),
    'max_depth' : [x for x in range(8, 20)],
    'reg_lambda' : np.linspace(2.2, 10, steps),
    'reg_alpha' : np.linspace(7, 10, steps),
    'scale_pos_weight' : np.linspace(1, 1.4, steps)
}

param_opt_dict = {param: [] for param in param_dict.keys()}

feature_importances_list = []

def get_nan_cabin_valid(X, y, pred):
    y = list(y)
    pred = list(pred)
    pred_true = []
    y_true = []
    i = 0
    for row in X.iterrows():
        if pd.isnull(row[1]['TransformedCabinDeck']):
            pred_true.append(pred[i])
            y_true.append(y[i])
        i += 1
    return accuracy_score(y_true, pred_true)

def get_sex_acc(X, y, pred, sex, class_list):
    y = list(y)
    pred = list(pred)
    y_women = []
    pred_women = []
    i = 0
    for row in X.iterrows():
        if row[1]['Sex'] == sex and row[1]['Pclass'] in class_list:
            y_women.append(y[i])
            pred_women.append(pred[i])
        i += 1
    return accuracy_score(y_women, pred_women)

best_score = 0
best_params = None

for i in range(n_trials):  # should be doing hypothesis testing maybe, or maybe that's a bad idea
    X, X_validation, y, y_validation = train_test_split(X_total, y_total, test_size=0.2, shuffle=True)

    skf = StratifiedKFold(n_splits=10)
    #skf = KFold(n_splits=5)

    steps = 80

    param_dict = {
        'learning_rate' : np.linspace(0.1, 0.9, steps),
        'gamma' : np.linspace(0.1, 3.5, steps),
        'max_depth' : [x for x in range(4, 20)],
        'reg_lambda' : np.linspace(.5, 10, steps),
        'reg_alpha' : np.linspace(0.1, 10, steps),
        'scale_pos_weight' : np.linspace(1, 1.35, steps)
    }

    random_grid = RandomizedSearchCV(
        estimator=XGBClassifier(),
        param_distributions=param_dict,
        scoring='accuracy',
        cv=skf.split(X, y),
        n_jobs=-1,
        n_iter=20,
        verbose=0
    )

    random_grid.fit(X, y)


    #print('results from test', i+1)
    print('best accuracy on cv set was', random_grid.best_score_)
    training_acc_list.append(random_grid.best_score_)

    params = random_grid.best_params_
    params['objective'] = 'binary:logistic'
    xgb_class = XGBRegressor(**params)
    fit = xgb_class.fit(X, y)
    pred = xgb_class.predict(X_validation).round()
    
    
    if not np.isnan(fit.feature_importances_).any():
        feature_importances_list.append(fit.feature_importances_)
    else:
        feature_importances_list.append(None)

    # check for overfitting (?)
    overfit_pred = xgb_class.predict(X_total).round()
    print('acc on training set is', accuracy_score(y_total, overfit_pred))
    # overfitting slightly
    
    print('accuracy on validation set was', accuracy_score(y_validation, pred))
    valid_acc_list.append(accuracy_score(y_validation, pred))
    
    if accuracy_score(y_validation, pred) > best_score:
        best_score = accuracy_score(y_validation, pred)
        best_params = random_grid.best_params_
    
    #print(get_nan_cabin_valid(X_validation, y_validation, pred))
    poor_women_acc_list.append(get_sex_acc(X_validation, y_validation, pred, 1, [0]))
    print('poor_women_acc is', poor_women_acc_list[-1])
    middle_women_acc_list.append(get_sex_acc(X_validation, y_validation, pred, 1, [1]))
    print('middle_women_acc is', middle_women_acc_list[-1])
    rich_women_acc_list.append(get_sex_acc(X_validation, y_validation, pred, 1, [2]))
    print('rich_women_acc is', rich_women_acc_list[-1])
    
    men_acc_list.append(get_sex_acc(X_validation, y_validation, pred, 0, [0, 10, 100]))
    
    print('f1_score for validation set is', f1_score(y_validation, pred))
    print('precision score for validation set is', precision_score(y_validation, pred))
    # what fraction of our selected items actually survived?
    print('recall score for validation set is', recall_score(y_validation, pred))
    #print(pred)
    # fraction of how many of the correctly predicted surviving / all of the actual surviving
    
    for param in random_grid.best_params_.keys():
        if param != 'objective':
            param_opt_dict[param].append((random_grid.best_params_[param], training_acc_list[-1]))

    print('best_params_ are', random_grid.best_params_)
    print('test', i, 'complete')
    print()
    
    
    
print('average training accuracy was', sum(training_acc_list) / n_trials)
# print('average validation accuracy was', sum(valid_acc_list) / n_trials)
# print('average men accuracy was', sum(men_acc_list) / n_trials)
# print('average poor women accuracy was', sum(poor_women_acc_list) / n_trials)
# print('average middle women accuracy was', sum(middle_women_acc_list) / n_trials)
# print('average rich women accuracy was', sum(rich_women_acc_list) / n_trials)

trace0 = go.Histogram(x=training_acc_list, opacity=0.5, name='train')
trace1 = go.Histogram(x=valid_acc_list, opacity=0.5, name='valid')

layout = go.Layout(barmode='stack')

py.iplot(go.Figure(data=[trace0, trace1], layout=layout))


# seems like I'm getting around 83% validation accuracy now...
# this is good enough I'll take it
# Out:
# (891, 20)
# best accuracy on cv set was 0.8426966292134831
# acc on training set is 0.8742985409652076
# accuracy on validation set was 0.8044692737430168
# poor_women_acc is 0.6774193548387096
# middle_women_acc is 0.875
# rich_women_acc is 1.0
# f1_score for validation set is 0.7517730496453902
# precision score for validation set is 0.7910447761194029
# recall score for validation set is 0.7162162162162162
# best_params_ are {'scale_pos_weight': 1.3101265822784811, 'reg_lambda': 7.3544303797468356, 'reg_alpha': 1.979746835443038, 'max_depth': 8, 'learning_rate': 0.1607594936708861, 'gamma': 0.7025316455696202, 'objective': 'binary:logistic'}
# test 0 complete
#
# best accuracy on cv set was 0.8384831460674157
# acc on training set is 0.8462401795735129
# accuracy on validation set was 0.776536312849162
# poor_women_acc is 0.5
# middle_women_acc is 0.9333333333333333
# rich_women_acc is 1.0
# f1_score for validation set is 0.7058823529411764
# precision score for validation set is 0.7741935483870968
# recall score for validation set is 0.6486486486486487
# best_params_ are {'scale_pos_weight': 1.3411392405063292, 'reg_lambda': 3.2658227848101267, 'reg_alpha': 8.245569620253164, 'max_depth': 11, 'learning_rate': 0.8291139240506329, 'gamma': 0.9177215189873418, 'objective': 'binary:logistic'}
# test 1 complete
#
# best accuracy on cv set was 0.8258426966292135
# acc on training set is 0.8305274971941639
# accuracy on validation set was 0.8324022346368715
# poor_women_acc is 0.6774193548387096
# middle_women_acc is 0.8666666666666667
# rich_women_acc is 1.0
# f1_score for validation set is 0.7761194029850745
# precision score for validation set is 0.8253968253968254
# recall score for validation set is 0.7323943661971831
# best_params_ are {'scale_pos_weight': 1.079746835443038, 'reg_lambda': 1.5822784810126582, 'reg_alpha': 8.872151898734177, 'max_depth': 16, 'learning_rate': 0.20126582278481014, 'gamma': 2.3810126582278484, 'objective': 'binary:logistic'}
# test 2 complete
#
# best accuracy on cv set was 0.8314606741573034
# acc on training set is 0.8552188552188552
# accuracy on validation set was 0.8324022346368715
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.9166666666666666
# rich_women_acc is 1.0
# f1_score for validation set is 0.7457627118644068
# precision score for validation set is 0.7586206896551724
# recall score for validation set is 0.7333333333333333
# best_params_ are {'scale_pos_weight': 1.2259493670886077, 'reg_lambda': 5.550632911392405, 'reg_alpha': 0.9772151898734177, 'max_depth': 16, 'learning_rate': 0.6772151898734177, 'gamma': 2.251898734177215, 'objective': 'binary:logistic'}
# test 3 complete
#
# best accuracy on cv set was 0.8356741573033708
# acc on training set is 0.8327721661054994
# accuracy on validation set was 0.8212290502793296
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.9090909090909091
# rich_women_acc is 0.9444444444444444
# f1_score for validation set is 0.7681159420289856
# precision score for validation set is 0.8153846153846154
# recall score for validation set is 0.726027397260274
# best_params_ are {'scale_pos_weight': 1.039873417721519, 'reg_lambda': 6.272151898734178, 'reg_alpha': 8.245569620253164, 'max_depth': 12, 'learning_rate': 0.2417721518987342, 'gamma': 1.0468354430379747, 'objective': 'binary:logistic'}
# test 4 complete
#
# best accuracy on cv set was 0.8216292134831461
# acc on training set is 0.8327721661054994
# accuracy on validation set was 0.8715083798882681
# poor_women_acc is 0.7083333333333334
# middle_women_acc is 0.8571428571428571
# rich_women_acc is 0.9411764705882353
# f1_score for validation set is 0.8
# precision score for validation set is 0.8214285714285714
# recall score for validation set is 0.7796610169491526
# best_params_ are {'scale_pos_weight': 1.1329113924050633, 'reg_lambda': 1.2215189873417722, 'reg_alpha': 6.992405063291139, 'max_depth': 5, 'learning_rate': 0.4544303797468354, 'gamma': 3.026582278481013, 'objective': 'binary:logistic'}
# test 5 complete
#
# best accuracy on cv set was 0.8384831460674157
# acc on training set is 0.8888888888888888
# accuracy on validation set was 0.8435754189944135
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.8888888888888888
# rich_women_acc is 1.0
# f1_score for validation set is 0.7999999999999999
# precision score for validation set is 0.7777777777777778
# recall score for validation set is 0.8235294117647058
# best_params_ are {'scale_pos_weight': 1.3322784810126582, 'reg_lambda': 3.386075949367089, 'reg_alpha': 2.9822784810126586, 'max_depth': 19, 'learning_rate': 0.839240506329114, 'gamma': 0.35822784810126584, 'objective': 'binary:logistic'}
# test 6 complete
#
# best accuracy on cv set was 0.8398876404494382
# acc on training set is 0.8619528619528619
# accuracy on validation set was 0.7877094972067039
# poor_women_acc is 0.5714285714285714
# middle_women_acc is 0.75
# rich_women_acc is 0.9545454545454546
# f1_score for validation set is 0.712121212121212
# precision score for validation set is 0.7704918032786885
# recall score for validation set is 0.6619718309859155
# best_params_ are {'scale_pos_weight': 1.150632911392405, 'reg_lambda': 9.037974683544304, 'reg_alpha': 0.1, 'max_depth': 11, 'learning_rate': 0.7987341772151899, 'gamma': 3.1126582278481014, 'objective': 'binary:logistic'}
# test 7 complete
#
# best accuracy on cv set was 0.827247191011236
# acc on training set is 0.8439955106621774
# accuracy on validation set was 0.8324022346368715
# poor_women_acc is 0.6896551724137931
# middle_women_acc is 1.0
# rich_women_acc is 0.9166666666666666
# f1_score for validation set is 0.7761194029850745
# precision score for validation set is 0.7878787878787878
# recall score for validation set is 0.7647058823529411
# best_params_ are {'scale_pos_weight': 1.031012658227848, 'reg_lambda': 9.037974683544304, 'reg_alpha': 3.107594936708861, 'max_depth': 17, 'learning_rate': 0.47468354430379744, 'gamma': 2.6822784810126583, 'objective': 'binary:logistic'}
# test 8 complete
#
# best accuracy on cv set was 0.8441011235955056
# acc on training set is 0.8428731762065096
# accuracy on validation set was 0.8268156424581006
# poor_women_acc is 0.7391304347826086
# middle_women_acc is 0.8125
# rich_women_acc is 1.0
# f1_score for validation set is 0.7633587786259541
# precision score for validation set is 0.819672131147541
# recall score for validation set is 0.7142857142857143
# best_params_ are {'scale_pos_weight': 1.2968354430379747, 'reg_lambda': 9.037974683544304, 'reg_alpha': 5.488607594936709, 'max_depth': 6, 'learning_rate': 0.15063291139240506, 'gamma': 1.5202531645569621, 'objective': 'binary:logistic'}
# test 9 complete
#
# best accuracy on cv set was 0.8160112359550562
# acc on training set is 0.8327721661054994
# accuracy on validation set was 0.88268156424581
# poor_women_acc is 0.7037037037037037
# middle_women_acc is 0.9
# rich_women_acc is 1.0
# f1_score for validation set is 0.823529411764706
# precision score for validation set is 0.8448275862068966
# recall score for validation set is 0.8032786885245902
# best_params_ are {'scale_pos_weight': 1.0575949367088608, 'reg_lambda': 5.189873417721519, 'reg_alpha': 9.498734177215189, 'max_depth': 15, 'learning_rate': 0.11012658227848102, 'gamma': 1.2620253164556963, 'objective': 'binary:logistic'}
# test 10 complete
#
# best accuracy on cv set was 0.8342696629213483
# acc on training set is 0.8843995510662177
# accuracy on validation set was 0.8268156424581006
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.9166666666666666
# rich_women_acc is 1.0
# f1_score for validation set is 0.7633587786259541
# precision score for validation set is 0.7692307692307693
# recall score for validation set is 0.7575757575757576
# best_params_ are {'scale_pos_weight': 1.1683544303797468, 'reg_lambda': 2.3037974683544302, 'reg_alpha': 1.729113924050633, 'max_depth': 12, 'learning_rate': 0.8696202531645569, 'gamma': 1.1759493670886076, 'objective': 'binary:logistic'}
# test 11 complete
#
# best accuracy on cv set was 0.8328651685393258
# acc on training set is 0.8338945005611672
# accuracy on validation set was 0.8268156424581006
# poor_women_acc is 0.5882352941176471
# middle_women_acc is 0.8947368421052632
# rich_women_acc is 1.0
# f1_score for validation set is 0.7703703703703704
# precision score for validation set is 0.7536231884057971
# recall score for validation set is 0.7878787878787878
# best_params_ are {'scale_pos_weight': 1.0443037974683544, 'reg_lambda': 9.518987341772153, 'reg_alpha': 2.3556962025316457, 'max_depth': 6, 'learning_rate': 0.2518987341772152, 'gamma': 2.467088607594937, 'objective': 'binary:logistic'}
# test 12 complete
# best accuracy on cv set was 0.8497191011235955
# acc on training set is 0.8518518518518519
# accuracy on validation set was 0.7653631284916201
# poor_women_acc is 0.59375
# middle_women_acc is 0.75
# rich_women_acc is 0.875
# f1_score for validation set is 0.65
# precision score for validation set is 0.7090909090909091
# recall score for validation set is 0.6
# best_params_ are {'scale_pos_weight': 1.2037974683544304, 'reg_lambda': 2.0632911392405067, 'reg_alpha': 7.243037974683544, 'max_depth': 11, 'learning_rate': 0.839240506329114, 'gamma': 1.089873417721519, 'objective': 'binary:logistic'}
# test 13 complete
#
# best accuracy on cv set was 0.8258426966292135
# acc on training set is 0.8294051627384961
# accuracy on validation set was 0.8324022346368715
# poor_women_acc is 0.6071428571428571
# middle_women_acc is 0.875
# rich_women_acc is 0.9230769230769231
# f1_score for validation set is 0.7413793103448276
# precision score for validation set is 0.7543859649122807
# recall score for validation set is 0.7288135593220338
# best_params_ are {'scale_pos_weight': 1.0, 'reg_lambda': 4.708860759493671, 'reg_alpha': 5.363291139240506, 'max_depth': 7, 'learning_rate': 0.11012658227848102, 'gamma': 2.8113924050632915, 'objective': 'binary:logistic'}
# test 14 complete
#
# best accuracy on cv set was 0.8497191011235955
# acc on training set is 0.867564534231201
# accuracy on validation set was 0.7932960893854749
# poor_women_acc is 0.5333333333333333
# middle_women_acc is 0.8666666666666667
# rich_women_acc is 0.9473684210526315
# f1_score for validation set is 0.7218045112781954
# precision score for validation set is 0.7619047619047619
# recall score for validation set is 0.6857142857142857
# best_params_ are {'scale_pos_weight': 1.1284810126582279, 'reg_lambda': 7.955696202531645, 'reg_alpha': 0.8518987341772152, 'max_depth': 5, 'learning_rate': 0.3227848101265823, 'gamma': 0.9607594936708861, 'objective': 'binary:logistic'}
# test 15 complete
#
# best accuracy on cv set was 0.8286516853932584
# acc on training set is 0.8552188552188552
# accuracy on validation set was 0.8435754189944135
# poor_women_acc is 0.6521739130434783
# middle_women_acc is 0.9166666666666666
# rich_women_acc is 1.0
# f1_score for validation set is 0.7704918032786884
# precision score for validation set is 0.8703703703703703
# recall score for validation set is 0.6911764705882353
# best_params_ are {'scale_pos_weight': 1.2569620253164557, 'reg_lambda': 8.917721518987342, 'reg_alpha': 0.35063291139240504, 'max_depth': 15, 'learning_rate': 0.6873417721518987, 'gamma': 2.5531645569620256, 'objective': 'binary:logistic'}
# test 16 complete
#
# best accuracy on cv set was 0.8370786516853933
# acc on training set is 0.8720538720538721
# accuracy on validation set was 0.8156424581005587
# poor_women_acc is 0.5
# middle_women_acc is 1.0
# rich_women_acc is 1.0
# f1_score for validation set is 0.7659574468085106
# precision score for validation set is 0.8059701492537313
# recall score for validation set is 0.7297297297297297
# best_params_ are {'scale_pos_weight': 1.2259493670886077, 'reg_lambda': 9.518987341772153, 'reg_alpha': 4.360759493670885, 'max_depth': 16, 'learning_rate': 0.6468354430379747, 'gamma': 0.2291139240506329, 'objective': 'binary:logistic'}
# test 17 complete
#
# best accuracy on cv set was 0.8356741573033708
# acc on training set is 0.8395061728395061
# accuracy on validation set was 0.7932960893854749
# poor_women_acc is 0.5151515151515151
# middle_women_acc is 0.8333333333333334
# rich_women_acc is 1.0
# f1_score for validation set is 0.7175572519083969
# precision score for validation set is 0.7014925373134329
# recall score for validation set is 0.734375
# best_params_ are {'scale_pos_weight': 1.0, 'reg_lambda': 0.620253164556962, 'reg_alpha': 8.621518987341771, 'max_depth': 10, 'learning_rate': 0.6670886075949367, 'gamma': 1.8645569620253166, 'objective': 'binary:logistic'}
# test 18 complete
#
# best accuracy on cv set was 0.8286516853932584
# acc on training set is 0.8417508417508418
# accuracy on validation set was 0.8491620111731844
# poor_women_acc is 0.6086956521739131
# middle_women_acc is 0.8888888888888888
# rich_women_acc is 1.0
# f1_score for validation set is 0.7476635514018692
# precision score for validation set is 0.8888888888888888
# recall score for validation set is 0.6451612903225806
# best_params_ are {'scale_pos_weight': 1.0930379746835444, 'reg_lambda': 2.5443037974683547, 'reg_alpha': 5.864556962025317, 'max_depth': 4, 'learning_rate': 0.7886075949367088, 'gamma': 3.5, 'objective': 'binary:logistic'}
# test 19 complete
#
# best accuracy on cv set was 0.8230337078651685
# acc on training set is 0.8327721661054994
# accuracy on validation set was 0.8547486033519553
# poor_women_acc is 0.6785714285714286
# middle_women_acc is 1.0
# rich_women_acc is 1.0
# f1_score for validation set is 0.7999999999999999
# precision score for validation set is 0.8387096774193549
# recall score for validation set is 0.7647058823529411
# best_params_ are {'scale_pos_weight': 1.3278481012658228, 'reg_lambda': 9.39873417721519, 'reg_alpha': 3.4835443037974687, 'max_depth': 19, 'learning_rate': 0.31265822784810127, 'gamma': 3.4139240506329114, 'objective': 'binary:logistic'}
# test 20 complete
#
# best accuracy on cv set was 0.8426966292134831
# acc on training set is 0.8518518518518519
# accuracy on validation set was 0.8100558659217877
# poor_women_acc is 0.6285714285714286
# middle_women_acc is 1.0
# rich_women_acc is 0.9473684210526315
# f1_score for validation set is 0.7462686567164178
# precision score for validation set is 0.7692307692307693
# recall score for validation set is 0.7246376811594203
# best_params_ are {'scale_pos_weight': 1.1373417721518988, 'reg_lambda': 9.879746835443038, 'reg_alpha': 8.99746835443038, 'max_depth': 10, 'learning_rate': 0.2417721518987342, 'gamma': 0.31518987341772153, 'objective': 'binary:logistic'}
# test 21 complete
#
# best accuracy on cv set was 0.8370786516853933
# acc on training set is 0.8327721661054994
# accuracy on validation set was 0.8044692737430168
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.9
# rich_women_acc is 0.9166666666666666
# f1_score for validation set is 0.6391752577319588
# precision score for validation set is 0.7380952380952381
# recall score for validation set is 0.5636363636363636
# best_params_ are {'scale_pos_weight': 1.2702531645569621, 'reg_lambda': 7.113924050632911, 'reg_alpha': 7.744303797468354, 'max_depth': 5, 'learning_rate': 0.19113924050632913, 'gamma': 3.4139240506329114, 'objective': 'binary:logistic'}
# test 22 complete
#
# best accuracy on cv set was 0.8441011235955056
# acc on training set is 0.8395061728395061
# accuracy on validation set was 0.7541899441340782
# poor_women_acc is 0.5454545454545454
# middle_women_acc is 0.9285714285714286
# rich_women_acc is 1.0
# f1_score for validation set is 0.6857142857142857
# precision score for validation set is 0.676056338028169
# recall score for validation set is 0.6956521739130435
# best_params_ are {'scale_pos_weight': 1.3101265822784811, 'reg_lambda': 6.753164556962026, 'reg_alpha': 5.363291139240506, 'max_depth': 9, 'learning_rate': 0.6873417721518987, 'gamma': 1.4341772151898735, 'objective': 'binary:logistic'}
# test 23 complete
#
# best accuracy on cv set was 0.824438202247191
# acc on training set is 0.8484848484848485
# accuracy on validation set was 0.8435754189944135
# poor_women_acc is 0.6521739130434783
# middle_women_acc is 0.8947368421052632
# rich_women_acc is 1.0
# f1_score for validation set is 0.7846153846153847
# precision score for validation set is 0.7846153846153846
# recall score for validation set is 0.7846153846153846
# best_params_ are {'scale_pos_weight': 1.1949367088607596, 'reg_lambda': 6.632911392405063, 'reg_alpha': 4.987341772151899, 'max_depth': 4, 'learning_rate': 0.5860759493670886, 'gamma': 0.9177215189873418, 'objective': 'binary:logistic'}
# test 24 complete
#
# best accuracy on cv set was 0.8455056179775281
# acc on training set is 0.8417508417508418
# accuracy on validation set was 0.7932960893854749
# poor_women_acc is 0.4444444444444444
# middle_women_acc is 0.8947368421052632
# rich_women_acc is 0.9444444444444444
# f1_score for validation set is 0.7338129496402879
# precision score for validation set is 0.7611940298507462
# recall score for validation set is 0.7083333333333334
# best_params_ are {'scale_pos_weight': 1.2658227848101267, 'reg_lambda': 8.556962025316455, 'reg_alpha': 6.115189873417721, 'max_depth': 10, 'learning_rate': 0.3329113924050633, 'gamma': 1.4772151898734178, 'objective': 'binary:logistic'}
# test 25 complete
# best accuracy on cv set was 0.8356741573033708
# acc on training set is 0.8507295173961841
# accuracy on validation set was 0.8324022346368715
# poor_women_acc is 0.6333333333333333
# middle_women_acc is 0.8571428571428571
# rich_women_acc is 1.0
# f1_score for validation set is 0.7794117647058824
# precision score for validation set is 0.7571428571428571
# recall score for validation set is 0.803030303030303
# best_params_ are {'scale_pos_weight': 1.2082278481012658, 'reg_lambda': 1.9430379746835444, 'reg_alpha': 3.984810126582279, 'max_depth': 6, 'learning_rate': 0.20126582278481014, 'gamma': 0.7455696202531645, 'objective': 'binary:logistic'}
# test 26 complete
#
# best accuracy on cv set was 0.8342696629213483
# acc on training set is 0.8383838383838383
# accuracy on validation set was 0.8044692737430168
# poor_women_acc is 0.6451612903225806
# middle_women_acc is 0.9333333333333333
# rich_women_acc is 0.9444444444444444
# f1_score for validation set is 0.7517730496453902
# precision score for validation set is 0.7361111111111112
# recall score for validation set is 0.7681159420289855
# best_params_ are {'scale_pos_weight': 1.1993670886075949, 'reg_lambda': 8.436708860759495, 'reg_alpha': 4.987341772151899, 'max_depth': 6, 'learning_rate': 0.6265822784810127, 'gamma': 1.907594936708861, 'objective': 'binary:logistic'}
# test 27 complete
#
# best accuracy on cv set was 0.824438202247191
# acc on training set is 0.867564534231201
# accuracy on validation set was 0.8547486033519553
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 0.8823529411764706
# rich_women_acc is 0.9523809523809523
# f1_score for validation set is 0.8243243243243245
# precision score for validation set is 0.782051282051282
# recall score for validation set is 0.8714285714285714
# best_params_ are {'scale_pos_weight': 1.150632911392405, 'reg_lambda': 9.518987341772153, 'reg_alpha': 1.6037974683544305, 'max_depth': 6, 'learning_rate': 0.7075949367088608, 'gamma': 0.6164556962025316, 'objective': 'binary:logistic'}
# test 28 complete
#
# best accuracy on cv set was 0.8216292134831461
# acc on training set is 0.8451178451178452
# accuracy on validation set was 0.8715083798882681
# poor_women_acc is 0.6666666666666666
# middle_women_acc is 1.0
# rich_women_acc is 1.0
# f1_score for validation set is 0.832116788321168
# precision score for validation set is 0.7702702702702703
# recall score for validation set is 0.9047619047619048
# best_params_ are {'scale_pos_weight': 1.3145569620253166, 'reg_lambda': 9.39873417721519, 'reg_alpha': 3.984810126582279, 'max_depth': 7, 'learning_rate': 0.20126582278481014, 'gamma': 1.6063291139240508, 'objective': 'binary:logistic'}
# test 29 complete
#
# average training accuracy was 0.8338951310861422
# ignoring the bad runs,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f7f5fbd51ebc> in <module>()
#     170
#     171 print('ignoring the bad runs,')
# --> 172 print('average training accuracy was', ignore_below_65(training_acc_list))
#     173 print('average validation accuracy was', ignore_below_65(valid_acc_list))
#     174
#
# NameError: name 'ignore_below_65' is not defined

# %%
pkl_params = True
if pkl_params:
    pkl.dump(best_params, open('xgb_best_params.pkl', 'wb'))

# %%
for param in param_opt_dict:
    x = []
    y = []
    param_opt_list = param_opt_dict[param]
    for (xs, ys) in param_opt_list:
        x.append(xs)
        y.append(ys)

    print(param)

    py.iplot([go.Scatter(x=x, y=y, mode='markers')])
# Out:
# learning_rate
# <div id="7c8ff41a-a24a-4792-a073-1a28cc5348db" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7c8ff41a-a24a-4792-a073-1a28cc5348db", [{"mode": "markers", "x": [0.7784810126582279, 0.5354430379746835, 0.5354430379746835, 0.839240506329114, 0.5962025316455697, 0.2721518987341772, 0.5759493670886076, 0.8696202531645569, 0.6367088607594936, 0.5759493670886076, 0.5050632911392405, 0.8088607594936709, 0.889873417721519, 0.20126582278481014, 0.6468354430379747, 0.839240506329114, 0.7481012658227848, 0.44430379746835447, 0.29240506329113924, 0.8696202531645569, 0.37341772151898733, 0.8189873417721519, 0.18101265822784812, 0.5962025316455697, 0.1, 0.6468354430379747, 0.4544303797468354, 0.29240506329113924, 0.6468354430379747, 0.1607594936708861], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eaed93b4-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# gamma
# <div id="9c37cf9c-05ed-4760-b033-ad46c0a4b508" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9c37cf9c-05ed-4760-b033-ad46c0a4b508", [{"mode": "markers", "x": [2.467088607594937, 0.5303797468354431, 3.5, 0.7886075949367088, 1.1329113924050633, 3.1126582278481014, 0.6164556962025316, 1.5632911392405064, 2.337974683544304, 2.079746835443038, 1.0037974683544304, 0.7455696202531645, 2.8544303797468356, 3.026582278481013, 0.1, 0.6164556962025316, 0.2721518987341772, 1.218987341772152, 1.218987341772152, 0.8316455696202532, 0.14303797468354432, 3.4139240506329114, 1.0037974683544304, 3.069620253164557, 3.241772151898734, 2.4240506329113924, 3.026582278481013, 2.4240506329113924, 2.639240506329114, 2.725316455696203], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eaf64fb8-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# max_depth
# <div id="ce16b386-8e26-4d13-9fde-d8a4309c7fe7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ce16b386-8e26-4d13-9fde-d8a4309c7fe7", [{"mode": "markers", "x": [12, 13, 6, 16, 4, 16, 17, 11, 9, 10, 17, 16, 18, 18, 11, 13, 15, 6, 9, 13, 17, 10, 4, 8, 7, 13, 8, 11, 12, 19], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eafda9ac-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# reg_lambda
# <div id="c48edf42-3db2-48b7-9268-0de9649a95cd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c48edf42-3db2-48b7-9268-0de9649a95cd", [{"mode": "markers", "x": [5.4303797468354436, 5.189873417721519, 5.189873417721519, 6.272151898734178, 4.588607594936709, 4.348101265822785, 1.3417721518987342, 7.113924050632911, 4.4683544303797476, 2.1835443037974684, 8.677215189873419, 8.79746835443038, 0.740506329113924, 4.708860759493671, 7.955696202531645, 5.791139240506329, 9.278481012658228, 9.639240506329115, 5.670886075949367, 5.670886075949367, 4.227848101265822, 6.272151898734178, 2.0632911392405067, 3.1455696202531644, 4.588607594936709, 4.348101265822785, 8.19620253164557, 6.753164556962026, 1.4620253164556962, 2.6645569620253164], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eb057d8a-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# reg_alpha
# <div id="07db2450-f111-48be-ae52-22ec8e0f5a92" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("07db2450-f111-48be-ae52-22ec8e0f5a92", [{"mode": "markers", "x": [5.112658227848101, 0.9772151898734177, 6.992405063291139, 4.110126582278481, 7.1177215189873415, 2.3556962025316457, 6.616455696202531, 1.1025316455696204, 1.1025316455696204, 4.110126582278481, 4.611392405063291, 6.741772151898734, 7.368354430379746, 9.874683544303798, 3.358227848101266, 6.992405063291139, 3.859493670886076, 3.4835443037974687, 4.360759493670885, 1.478481012658228, 8.872151898734177, 8.872151898734177, 4.4860759493670885, 3.4835443037974687, 9.874683544303798, 3.107594936708861, 9.498734177215189, 9.498734177215189, 7.869620253164557, 8.120253164556962], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eb0d28be-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# scale_pos_weight
# <div id="74453683-eb5f-4fd8-86a3-90bbc2aa3bb5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("74453683-eb5f-4fd8-86a3-90bbc2aa3bb5", [{"mode": "markers", "x": [1.0, 1.3101265822784811, 1.1860759493670887, 1.2215189873417722, 1.150632911392405, 1.0841772151898734, 1.3278481012658228, 1.3411392405063292, 1.2658227848101267, 1.1063291139240508, 1.1772151898734178, 1.2436708860759493, 1.1329113924050633, 1.1683544303797468, 1.0664556962025316, 1.1816455696202532, 1.1462025316455697, 1.2392405063291139, 1.031012658227848, 1.159493670886076, 1.35, 1.3012658227848102, 1.1860759493670887, 1.04873417721519, 1.1949367088607596, 1.1373417721518988, 1.0930379746835444, 1.3012658227848102, 1.2303797468354432, 1.0221518987341773], "y": [0.8212290502793296, 0.8379888268156425, 0.8324022346368715, 0.8212290502793296, 0.8324022346368715, 0.8324022346368715, 0.8268156424581006, 0.8044692737430168, 0.8603351955307262, 0.8770949720670391, 0.8547486033519553, 0.8100558659217877, 0.7988826815642458, 0.8212290502793296, 0.8379888268156425, 0.7932960893854749, 0.8044692737430168, 0.8156424581005587, 0.8100558659217877, 0.8379888268156425, 0.8435754189944135, 0.8212290502793296, 0.770949720670391, 0.7821229050279329, 0.8547486033519553, 0.8268156424581006, 0.770949720670391, 0.8324022346368715, 0.8603351955307262, 0.8324022346368715], "type": "scatter", "uid": "eb1586e4-a36a-11e8-889b-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
cols = [col for col in X_total.columns]

for i in range(len(cols)):
    print(cols[i], ':\t\t\t', round(sum([row[i] for row in feature_importances_list]) * 100 / n_trials, 3))
# Out:
# Pclass :			 12.411
# Sex :			 7.184
# Age :			 8.095
# SibSp :			 0.603
# Parch :			 0.145
# Fare :			 14.27
# Salutation :			 10.197
# NumRelatives :			 6.341
# HasFamily :			 0.0
# LastNameOccurance :			 3.057
# TicketOccurance :			 6.132
# IsBritish :			 0.537
# TransformedCabinDeck :			 10.555
# BoardedAtSouthamption :			 1.636
# BoardedAtQueenstown :			 0.743
# BoardedAtCherbourg :			 2.092
# IsAlone :			 0.0
# AgeLogFare :			 12.879
# YouthFamilyScore :			 3.122
