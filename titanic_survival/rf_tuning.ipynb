# %%
import pandas as pd
import numpy as np

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(True)

from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv('df_after_engineering.csv')
df = df.drop('TransformedCabinDeck', axis=1)
df = df.dropna()
df.shape

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, KFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

import warnings
warnings.filterwarnings('ignore')

data = df.drop('PassengerId', axis=1)
#data = data.drop('TransformedCabinDeck', axis=1)

# lets see if we can identify a subset where the model does very well
#data = data.where(data['Sex'] == 1).dropna()
#print(data)
X_total = data.drop('Survived', axis=1)
#X_total = X_total.drop('IsAlone', axis=1)
y_total = data['Survived']

# lets keep a validation set as a sanity check
training_acc_list = []
valid_acc_list = []
n_trials = 20

param_opt_list = []

feature_importances_list = []

for i in range(n_trials):  # should be doing hypothesis testing maybe, or maybe that's a bad idea
    X, X_validation, y, y_validation = train_test_split(X_total, y_total, test_size=0.2, shuffle=True)

    skf = StratifiedKFold(n_splits=5)
    #skf = KFold(n_splits=5)

    steps = 100
    
    """
    RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
    """


    param_dict = {
        'max_leaf_nodes' : [i for i in range(50, 100)],
        'min_samples_leaf' : [i for i in range(1, 100)],
        'max_depth' : [i for i in range(5, 20)],
        'min_samples_split' : [i for i in range(2, 40)],
        #'n_jobs' : [-1],
        #'min_impurity_decrase' : np.linspace(0.1, 0.3, steps),
        'min_weight_fraction_leaf' : np.linspace(0, 0.3, steps)
    }

    random_grid = RandomizedSearchCV(
        estimator=RandomForestClassifier(),
        param_distributions=param_dict,
        scoring='accuracy',
        cv=skf.split(X, y),
        n_jobs=-1,
        n_iter=20,
        verbose=0
    )

    random_grid.fit(X, y)

    #print('results from test', i+1)
    print('best accuracy on cv set was', random_grid.best_score_)
    training_acc_list.append(random_grid.best_score_)
       
    rfc = RandomForestClassifier(**random_grid.best_params_)
    rfc.fit(X, y)
    pred = rfc.predict(X_validation)

    # check for overfitting (?)
    overfit_pred = rfc.predict(X)
    print('acc on training set is', accuracy_score(y, overfit_pred))
    
    print('accuracy on validation set was', accuracy_score(y_validation, pred))
    valid_acc_list.append(accuracy_score(y_validation, pred))
    print('f1_score for validation set is', f1_score(y_validation, pred))
    print('precision score for validation set is', precision_score(y_validation, pred))
    # what fraction of our selected items actually survived?
    print('recall score for validation set is', recall_score(y_validation, pred))
    # fraction of how many of the correctly predicted surviving / all of the actual surviving
    print('best_params_ are', random_grid.best_params_)
    print('test', i, 'complete')
    print()
    
    #opt_param = 'max_depth'
    #param_opt_list.append((random_grid.best_params_[opt_param], valid_acc_list[-1]))
    
print('average training accuracy was', sum(training_acc_list) / n_trials)
print('average validation accuracy was', sum(valid_acc_list) / n_trials)

trace0 = go.Histogram(x=training_acc_list, opacity=0.5, name='train')
trace1 = go.Histogram(x=valid_acc_list, opacity=0.5, name='valid')

layout = go.Layout(barmode='stack')

py.iplot(go.Figure(data=[trace0, trace1], layout=layout))
# Out:
# best accuracy on cv set was 0.8283712784588442
# acc on training set is 0.8476357267950964
# accuracy on validation set was 0.7552447552447552
# f1_score for validation set is 0.7154471544715447
# precision score for validation set is 0.7857142857142857
# recall score for validation set is 0.6567164179104478
# best_params_ are {'min_weight_fraction_leaf': 0.015151515151515152, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_leaf_nodes': 97, 'max_depth': 7}
# test 0 complete
#
# best accuracy on cv set was 0.809106830122592
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.8181818181818182
# f1_score for validation set is 0.7968749999999999
# precision score for validation set is 0.8095238095238095
# recall score for validation set is 0.7846153846153846
# best_params_ are {'min_weight_fraction_leaf': 0.03333333333333333, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_leaf_nodes': 62, 'max_depth': 9}
# test 1 complete
#
# best accuracy on cv set was 0.8038528896672504
# acc on training set is 0.7950963222416813
# accuracy on validation set was 0.7902097902097902
# f1_score for validation set is 0.7222222222222223
# precision score for validation set is 0.78
# recall score for validation set is 0.6724137931034483
# best_params_ are {'min_weight_fraction_leaf': 0.04242424242424243, 'min_samples_split': 11, 'min_samples_leaf': 30, 'max_leaf_nodes': 91, 'max_depth': 10}
# test 2 complete
#
# best accuracy on cv set was 0.8476357267950964
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.7412587412587412
# f1_score for validation set is 0.6725663716814159
# precision score for validation set is 0.7037037037037037
# recall score for validation set is 0.6440677966101694
# best_params_ are {'min_weight_fraction_leaf': 0.006060606060606061, 'min_samples_split': 36, 'min_samples_leaf': 14, 'max_leaf_nodes': 89, 'max_depth': 16}
# test 3 complete
#
# best accuracy on cv set was 0.8108581436077058
# acc on training set is 0.8546409807355516
# accuracy on validation set was 0.8531468531468531
# f1_score for validation set is 0.7961165048543688
# precision score for validation set is 0.803921568627451
# recall score for validation set is 0.7884615384615384
# best_params_ are {'min_weight_fraction_leaf': 0.024242424242424242, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_leaf_nodes': 71, 'max_depth': 18}
# test 4 complete
#
# best accuracy on cv set was 0.7915936952714536
# acc on training set is 0.8056042031523643
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.7751937984496124
# precision score for validation set is 0.746268656716418
# recall score for validation set is 0.8064516129032258
# best_params_ are {'min_weight_fraction_leaf': 0.11515151515151516, 'min_samples_split': 14, 'min_samples_leaf': 18, 'max_leaf_nodes': 50, 'max_depth': 19}
# test 5 complete
#
# best accuracy on cv set was 0.7933450087565674
# acc on training set is 0.8126094570928196
# accuracy on validation set was 0.7692307692307693
# f1_score for validation set is 0.6666666666666666
# precision score for validation set is 0.9705882352941176
# recall score for validation set is 0.5076923076923077
# best_params_ are {'min_weight_fraction_leaf': 0.11515151515151516, 'min_samples_split': 11, 'min_samples_leaf': 22, 'max_leaf_nodes': 78, 'max_depth': 5}
# test 6 complete
#
# best accuracy on cv set was 0.7933450087565674
# acc on training set is 0.861646234676007
# accuracy on validation set was 0.8671328671328671
# f1_score for validation set is 0.8190476190476189
# precision score for validation set is 0.7962962962962963
# recall score for validation set is 0.8431372549019608
# best_params_ are {'min_weight_fraction_leaf': 0.0030303030303030303, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_leaf_nodes': 55, 'max_depth': 15}
# test 7 complete
#
# best accuracy on cv set was 0.7933450087565674
# acc on training set is 0.7880910683012259
# accuracy on validation set was 0.7762237762237763
# f1_score for validation set is 0.6521739130434782
# precision score for validation set is 0.6382978723404256
# recall score for validation set is 0.6666666666666666
# best_params_ are {'min_weight_fraction_leaf': 0.14242424242424243, 'min_samples_split': 16, 'min_samples_leaf': 35, 'max_leaf_nodes': 94, 'max_depth': 10}
# test 8 complete
#
# best accuracy on cv set was 0.8231173380035026
# acc on training set is 0.8704028021015762
# accuracy on validation set was 0.8181818181818182
# f1_score for validation set is 0.7636363636363638
# precision score for validation set is 0.7777777777777778
# recall score for validation set is 0.75
# best_params_ are {'min_weight_fraction_leaf': 0.0030303030303030303, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_leaf_nodes': 58, 'max_depth': 12}
# test 9 complete
#
# best accuracy on cv set was 0.7863397548161121
# acc on training set is 0.7828371278458844
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.7474747474747474
# precision score for validation set is 0.74
# recall score for validation set is 0.7551020408163265
# best_params_ are {'min_weight_fraction_leaf': 0.08484848484848485, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_leaf_nodes': 68, 'max_depth': 8}
# test 10 complete
#
# best accuracy on cv set was 0.7723292469352014
# acc on training set is 0.7845884413309983
# accuracy on validation set was 0.8461538461538461
# f1_score for validation set is 0.7708333333333333
# precision score for validation set is 0.7708333333333334
# recall score for validation set is 0.7708333333333334
# best_params_ are {'min_weight_fraction_leaf': 0.2606060606060606, 'min_samples_split': 9, 'min_samples_leaf': 69, 'max_leaf_nodes': 75, 'max_depth': 11}
# test 11 complete
#
# best accuracy on cv set was 0.8213660245183888
# acc on training set is 0.8458844133099825
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.7747747747747747
# precision score for validation set is 0.7962962962962963
# recall score for validation set is 0.7543859649122807
# best_params_ are {'min_weight_fraction_leaf': 0.045454545454545456, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_leaf_nodes': 74, 'max_depth': 19}
# test 12 complete
#
# best accuracy on cv set was 0.7985989492119089
# acc on training set is 0.8143607705779334
# accuracy on validation set was 0.8111888111888111
# f1_score for validation set is 0.7731092436974789
# precision score for validation set is 0.8070175438596491
# recall score for validation set is 0.7419354838709677
# best_params_ are {'min_weight_fraction_leaf': 0.06060606060606061, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_leaf_nodes': 75, 'max_depth': 16}
# test 13 complete
#
# best accuracy on cv set was 0.8038528896672504
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.8671328671328671
# f1_score for validation set is 0.8224299065420562
# precision score for validation set is 0.8
# recall score for validation set is 0.8461538461538461
# best_params_ are {'min_weight_fraction_leaf': 0.024242424242424242, 'min_samples_split': 23, 'min_samples_leaf': 3, 'max_leaf_nodes': 74, 'max_depth': 14}
# test 14 complete
#
# best accuracy on cv set was 0.8266199649737302
# acc on training set is 0.8318739054290718
# accuracy on validation set was 0.8391608391608392
# f1_score for validation set is 0.7294117647058824
# precision score for validation set is 0.7948717948717948
# recall score for validation set is 0.6739130434782609
# best_params_ are {'min_weight_fraction_leaf': 0.05757575757575758, 'min_samples_split': 26, 'min_samples_leaf': 13, 'max_leaf_nodes': 73, 'max_depth': 14}
# test 15 complete
#
# best accuracy on cv set was 0.7968476357267951
# acc on training set is 0.8143607705779334
# accuracy on validation set was 0.7622377622377622
# f1_score for validation set is 0.7166666666666667
# precision score for validation set is 0.7166666666666667
# recall score for validation set is 0.7166666666666667
# best_params_ are {'min_weight_fraction_leaf': 0.10303030303030303, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_leaf_nodes': 91, 'max_depth': 8}
# test 16 complete
#
# best accuracy on cv set was 0.8073555166374781
# acc on training set is 0.8371278458844134
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.7238095238095238
# precision score for validation set is 0.8636363636363636
# recall score for validation set is 0.6229508196721312
# best_params_ are {'min_weight_fraction_leaf': 0.051515151515151514, 'min_samples_split': 21, 'min_samples_leaf': 20, 'max_leaf_nodes': 86, 'max_depth': 10}
# test 17 complete
# best accuracy on cv set was 0.7863397548161121
# acc on training set is 0.8231173380035026
# accuracy on validation set was 0.7902097902097902
# f1_score for validation set is 0.7222222222222223
# precision score for validation set is 0.75
# recall score for validation set is 0.6964285714285714
# best_params_ are {'min_weight_fraction_leaf': 0.012121212121212121, 'min_samples_split': 39, 'min_samples_leaf': 21, 'max_leaf_nodes': 50, 'max_depth': 11}
# test 18 complete
#
# best accuracy on cv set was 0.8161120840630472
# acc on training set is 0.8546409807355516
# accuracy on validation set was 0.7902097902097902
# f1_score for validation set is 0.7500000000000001
# precision score for validation set is 0.8181818181818182
# recall score for validation set is 0.6923076923076923
# best_params_ are {'min_weight_fraction_leaf': 0.030303030303030304, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_leaf_nodes': 66, 'max_depth': 18}
# test 19 complete
#
# average training accuracy was 0.8055166374781086
# average validation accuracy was 0.806993006993007
# <div id="f2f8d5f3-881d-4dce-980d-53861c82ca01" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'f2f8d5f3-881d-4dce-980d-53861c82ca01',
#             [{"name": "train", "opacity": 0.5, "x": [0.8283712784588442, 0.809106830122592, 0.8038528896672504, 0.8476357267950964, 0.8108581436077058, 0.7915936952714536, 0.7933450087565674, 0.7933450087565674, 0.7933450087565674, 0.8231173380035026, 0.7863397548161121, 0.7723292469352014, 0.8213660245183888, 0.7985989492119089, 0.8038528896672504, 0.8266199649737302, 0.7968476357267951, 0.8073555166374781, 0.7863397548161121, 0.8161120840630472], "type": "histogram", "uid": "c43ecfd2-a291-11e8-9ca4-88e9fe7b2dc1"}, {"name": "valid", "opacity": 0.5, "x": [0.7552447552447552, 0.8181818181818182, 0.7902097902097902, 0.7412587412587412, 0.8531468531468531, 0.7972027972027972, 0.7692307692307693, 0.8671328671328671, 0.7762237762237763, 0.8181818181818182, 0.8251748251748252, 0.8461538461538461, 0.8251748251748252, 0.8111888111888111, 0.8671328671328671, 0.8391608391608392, 0.7622377622377622, 0.7972027972027972, 0.7902097902097902, 0.7902097902097902], "type": "histogram", "uid": "c43ed2b6-a291-11e8-9ca4-88e9fe7b2dc1"}],
#             {"barmode": "stack"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('f2f8d5f3-881d-4dce-980d-53861c82ca01',{});}).then(function(){Plotly.animate('f2f8d5f3-881d-4dce-980d-53861c82ca01');})
#         });</script>
