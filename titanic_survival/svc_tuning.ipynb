# %%
import pandas as pd
import numpy as np
import pickle as pkl

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(True)

from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv('df_after_engineering.csv')
df = df.drop('TransformedCabinDeck', axis=1)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, KFold, train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

data = df.drop('PassengerId', axis=1)
data = data.dropna()
#data = data.where(np.logical_and(data['Sex'] == 1, data['Pclass'] == 0)).dropna()
data = data.drop(['IsAlone', 'NumRelatives'], axis=1)
print(data.columns)

steps=1
param_dict = {
        'C' : np.linspace(0.5, 20, steps),
        'kernel' : ['rbf'],
        'gamma' : np.linspace(0.01, 0.1, steps),
        'coef0' : np.linspace(1, 10, steps),
    }

param_opt_dict = {param: [] for param in param_dict.keys()}

# lets see if we can identify a subset where the model does very well
#data = data.where(data['Sex'] == 1).dropna()
#data = data.where(data['Pclass'] == 0).dropna()
print(data.shape)
X_total = data.drop('Survived', axis=1)
X_total = StandardScaler().fit_transform(X_total)
y_total = data['Survived']

# lets keep a validation set as a sanity check
training_acc_list = []
valid_acc_list = []
n_trials = 30

param_opt_list = []

feature_importances_list = []

best_params = None
best_score = 0

for i in range(n_trials):  # should be doing hypothesis testing maybe, or maybe that's a bad idea
    X, X_validation, y, y_validation = train_test_split(X_total, y_total, test_size=0.2, shuffle=True)

    skf = StratifiedKFold(n_splits=5)
    #skf = KFold(n_splits=5)

    steps = 80


    param_dict = {
        'C' : np.linspace(0.5, 20, steps),
        'kernel' : ['rbf'],
        'gamma' : np.linspace(0.01, 0.04, steps),
        'coef0' : np.linspace(0, 10, steps),
    }

    random_grid = RandomizedSearchCV(
        estimator=SVC(),
        param_distributions=param_dict,
        scoring='accuracy',
        cv=skf.split(X, y),
        n_jobs=-1,
        n_iter=10,
        verbose=0
    )

    random_grid.fit(X, y)

    #print('results from test', i+1)
    print('best accuracy on cv set was', random_grid.best_score_)
    training_acc_list.append(random_grid.best_score_)
       
    svc = SVC(**random_grid.best_params_)
    svc.fit(X, y)
    pred = svc.predict(X_validation)

    # check for overfitting (?)
    overfit_pred = svc.predict(X)
    print('acc on training set is', accuracy_score(y, overfit_pred))
    
    print('accuracy on validation set was', accuracy_score(y_validation, pred))
    valid_acc_list.append(accuracy_score(y_validation, pred))
    
    if accuracy_score(y_validation, pred) > best_score:
        best_score = accuracy_score(y_validation, pred)
        best_params = random_grid.best_params_
    
    print('f1_score for validation set is', f1_score(y_validation, pred))
    print('precision score for validation set is', precision_score(y_validation, pred))
    # what fraction of our selected items actually survived?
    print('recall score for validation set is', recall_score(y_validation, pred))
    # fraction of how many of the correctly predicted surviving / all of the actual surviving
    print('best_params_ are', random_grid.best_params_)
    print('test', i, 'complete')
    print()
    
    for param in param_dict:
        param_opt_dict[param].append((random_grid.best_params_[param], valid_acc_list[-1]))
    
print('average training accuracy was', sum(training_acc_list) / n_trials)
print('average validation accuracy was', sum(valid_acc_list) / n_trials)

trace0 = go.Histogram(x=training_acc_list, opacity=0.5, name='train')
trace1 = go.Histogram(x=valid_acc_list, opacity=0.5, name='valid')

layout = go.Layout(barmode='stack')

py.iplot(go.Figure(data=[trace0, trace1], layout=layout))
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Salutation', 'HasFamily', 'LastNameOccurance', 'TicketOccurance',
#        'IsBritish', 'BoardedAtSouthamption', 'BoardedAtQueenstown',
#        'BoardedAtCherbourg', 'AgeLogFare', 'YouthFamilyScore'],
#       dtype='object')
# (714, 17)
# best accuracy on cv set was 0.8318739054290718
# acc on training set is 0.840630472854641
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.7387387387387387
# precision score for validation set is 0.7735849056603774
# recall score for validation set is 0.7068965517241379
# best_params_ are {'kernel': 'rbf', 'gamma': 0.022531645569620253, 'coef0': 5.189873417721519, 'C': 2.227848101265823}
# test 0 complete
#
# best accuracy on cv set was 0.8073555166374781
# acc on training set is 0.8546409807355516
# accuracy on validation set was 0.8461538461538461
# f1_score for validation set is 0.7843137254901962
# precision score for validation set is 0.8163265306122449
# recall score for validation set is 0.7547169811320755
# best_params_ are {'kernel': 'rbf', 'gamma': 0.018734177215189874, 'coef0': 8.60759493670886, 'C': 15.063291139240507}
# test 1 complete
#
# best accuracy on cv set was 0.8231173380035026
# acc on training set is 0.8563922942206655
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.7422680412371134
# precision score for validation set is 0.782608695652174
# recall score for validation set is 0.7058823529411765
# best_params_ are {'kernel': 'rbf', 'gamma': 0.011139240506329114, 'coef0': 8.734177215189874, 'C': 18.27215189873418}
# test 2 complete
#
# best accuracy on cv set was 0.8423817863397548
# acc on training set is 0.8581436077057794
# accuracy on validation set was 0.7622377622377622
# f1_score for validation set is 0.7166666666666666
# precision score for validation set is 0.7288135593220338
# recall score for validation set is 0.7049180327868853
# best_params_ are {'kernel': 'rbf', 'gamma': 0.03088607594936709, 'coef0': 3.924050632911393, 'C': 3.708860759493671}
# test 3 complete
#
# best accuracy on cv set was 0.8178633975481612
# acc on training set is 0.8371278458844134
# accuracy on validation set was 0.8041958041958042
# f1_score for validation set is 0.7704918032786884
# precision score for validation set is 0.7833333333333333
# recall score for validation set is 0.7580645161290323
# best_params_ are {'kernel': 'rbf', 'gamma': 0.036582278481012656, 'coef0': 5.69620253164557, 'C': 1.240506329113924}
# test 4 complete
#
# best accuracy on cv set was 0.8231173380035026
# acc on training set is 0.8441330998248686
# accuracy on validation set was 0.8321678321678322
# f1_score for validation set is 0.7857142857142856
# precision score for validation set is 0.8461538461538461
# recall score for validation set is 0.7333333333333333
# best_params_ are {'kernel': 'rbf', 'gamma': 0.017974683544303798, 'coef0': 6.835443037974684, 'C': 4.943037974683545}
# test 5 complete
#
# best accuracy on cv set was 0.8248686514886164
# acc on training set is 0.8493870402802102
# accuracy on validation set was 0.8531468531468531
# f1_score for validation set is 0.8173913043478261
# precision score for validation set is 0.8867924528301887
# recall score for validation set is 0.7580645161290323
# best_params_ are {'kernel': 'rbf', 'gamma': 0.016455696202531647, 'coef0': 8.481012658227849, 'C': 9.139240506329115}
# test 6 complete
#
# best accuracy on cv set was 0.8213660245183888
# acc on training set is 0.8493870402802102
# accuracy on validation set was 0.8391608391608392
# f1_score for validation set is 0.7766990291262137
# precision score for validation set is 0.8163265306122449
# recall score for validation set is 0.7407407407407407
# best_params_ are {'kernel': 'rbf', 'gamma': 0.03810126582278481, 'coef0': 1.6455696202531647, 'C': 2.227848101265823}
# test 7 complete
#
# best accuracy on cv set was 0.819614711033275
# acc on training set is 0.8546409807355516
# accuracy on validation set was 0.8461538461538461
# f1_score for validation set is 0.7924528301886793
# precision score for validation set is 0.9130434782608695
# recall score for validation set is 0.7
# best_params_ are {'kernel': 'rbf', 'gamma': 0.018734177215189874, 'coef0': 2.9113924050632916, 'C': 7.658227848101266}
# test 8 complete
#
# best accuracy on cv set was 0.8266199649737302
# acc on training set is 0.8563922942206655
# accuracy on validation set was 0.8111888111888111
# f1_score for validation set is 0.737864077669903
# precision score for validation set is 0.8085106382978723
# recall score for validation set is 0.6785714285714286
# best_params_ are {'kernel': 'rbf', 'gamma': 0.022531645569620253, 'coef0': 0.6329113924050633, 'C': 3.4620253164556964}
# test 9 complete
#
# best accuracy on cv set was 0.8336252189141856
# acc on training set is 0.8651488616462347
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.7070707070707072
# precision score for validation set is 0.7142857142857143
# recall score for validation set is 0.7
# best_params_ are {'kernel': 'rbf', 'gamma': 0.026329113924050636, 'coef0': 1.3924050632911393, 'C': 7.658227848101266}
# test 10 complete
#
# best accuracy on cv set was 0.8213660245183888
# acc on training set is 0.8633975481611208
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.7747747747747747
# precision score for validation set is 0.8431372549019608
# recall score for validation set is 0.7166666666666667
# best_params_ are {'kernel': 'rbf', 'gamma': 0.018354430379746836, 'coef0': 2.0253164556962027, 'C': 8.645569620253164}
# test 11 complete
#
# best accuracy on cv set was 0.8178633975481612
# acc on training set is 0.8371278458844134
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.782608695652174
# precision score for validation set is 0.8490566037735849
# recall score for validation set is 0.7258064516129032
# best_params_ are {'kernel': 'rbf', 'gamma': 0.02329113924050633, 'coef0': 9.620253164556964, 'C': 2.4746835443037973}
# test 12 complete
#
# best accuracy on cv set was 0.840630472854641
# acc on training set is 0.8598949211908932
# accuracy on validation set was 0.7552447552447552
# f1_score for validation set is 0.6788990825688075
# precision score for validation set is 0.7115384615384616
# recall score for validation set is 0.6491228070175439
# best_params_ are {'kernel': 'rbf', 'gamma': 0.010379746835443038, 'coef0': 9.873417721518988, 'C': 18.27215189873418}
# test 13 complete
#
# best accuracy on cv set was 0.830122591943958
# acc on training set is 0.8704028021015762
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.7387387387387386
# precision score for validation set is 0.7884615384615384
# recall score for validation set is 0.6949152542372882
# best_params_ are {'kernel': 'rbf', 'gamma': 0.02518987341772152, 'coef0': 1.3924050632911393, 'C': 5.436708860759494}
# test 14 complete
#
# best accuracy on cv set was 0.8108581436077058
# acc on training set is 0.8371278458844134
# accuracy on validation set was 0.8881118881118881
# f1_score for validation set is 0.8571428571428572
# precision score for validation set is 0.9056603773584906
# recall score for validation set is 0.8135593220338984
# best_params_ are {'kernel': 'rbf', 'gamma': 0.01189873417721519, 'coef0': 1.139240506329114, 'C': 11.360759493670887}
# test 15 complete
#
# best accuracy on cv set was 0.8231173380035026
# acc on training set is 0.8371278458844134
# accuracy on validation set was 0.8181818181818182
# f1_score for validation set is 0.7291666666666667
# precision score for validation set is 0.7608695652173914
# recall score for validation set is 0.7
# best_params_ are {'kernel': 'rbf', 'gamma': 0.01949367088607595, 'coef0': 3.1645569620253164, 'C': 4.2025316455696204}
# test 16 complete
#
# best accuracy on cv set was 0.819614711033275
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.8601398601398601
# f1_score for validation set is 0.803921568627451
# precision score for validation set is 0.8723404255319149
# recall score for validation set is 0.7454545454545455
# best_params_ are {'kernel': 'rbf', 'gamma': 0.010379746835443038, 'coef0': 0.379746835443038, 'C': 13.58227848101266}
# test 17 complete
#
# best accuracy on cv set was 0.8108581436077058
# acc on training set is 0.8633975481611208
# accuracy on validation set was 0.8321678321678322
# f1_score for validation set is 0.7777777777777777
# precision score for validation set is 0.875
# recall score for validation set is 0.7
# best_params_ are {'kernel': 'rbf', 'gamma': 0.017215189873417722, 'coef0': 6.708860759493671, 'C': 13.08860759493671}
# test 18 complete
# best accuracy on cv set was 0.8161120840630472
# acc on training set is 0.851138353765324
# accuracy on validation set was 0.8461538461538461
# f1_score for validation set is 0.7962962962962963
# precision score for validation set is 0.9148936170212766
# recall score for validation set is 0.7049180327868853
# best_params_ are {'kernel': 'rbf', 'gamma': 0.014556962025316457, 'coef0': 4.4303797468354436, 'C': 8.645569620253164}
# test 19 complete
#
# best accuracy on cv set was 0.8231173380035026
# acc on training set is 0.861646234676007
# accuracy on validation set was 0.8111888111888111
# f1_score for validation set is 0.7610619469026548
# precision score for validation set is 0.8113207547169812
# recall score for validation set is 0.7166666666666667
# best_params_ are {'kernel': 'rbf', 'gamma': 0.021772151898734177, 'coef0': 1.139240506329114, 'C': 6.670886075949367}
# test 20 complete
#
# best accuracy on cv set was 0.8371278458844134
# acc on training set is 0.8493870402802102
# accuracy on validation set was 0.7972027972027972
# f1_score for validation set is 0.712871287128713
# precision score for validation set is 0.8181818181818182
# recall score for validation set is 0.631578947368421
# best_params_ are {'kernel': 'rbf', 'gamma': 0.03050632911392405, 'coef0': 2.7848101265822787, 'C': 2.7215189873417724}
# test 21 complete
#
# best accuracy on cv set was 0.8161120840630472
# acc on training set is 0.8353765323992994
# accuracy on validation set was 0.8531468531468531
# f1_score for validation set is 0.8205128205128206
# precision score for validation set is 0.9056603773584906
# recall score for validation set is 0.75
# best_params_ are {'kernel': 'rbf', 'gamma': 0.02518987341772152, 'coef0': 1.2658227848101267, 'C': 3.4620253164556964}
# test 22 complete
#
# best accuracy on cv set was 0.8266199649737302
# acc on training set is 0.8739054290718039
# accuracy on validation set was 0.8321678321678322
# f1_score for validation set is 0.7818181818181819
# precision score for validation set is 0.7678571428571429
# recall score for validation set is 0.7962962962962963
# best_params_ are {'kernel': 'rbf', 'gamma': 0.018354430379746836, 'coef0': 4.556962025316456, 'C': 15.063291139240507}
# test 23 complete
#
# best accuracy on cv set was 0.8248686514886164
# acc on training set is 0.8423817863397548
# accuracy on validation set was 0.8601398601398601
# f1_score for validation set is 0.8333333333333334
# precision score for validation set is 0.8928571428571429
# recall score for validation set is 0.78125
# best_params_ are {'kernel': 'rbf', 'gamma': 0.030126582278481015, 'coef0': 2.6582278481012658, 'C': 2.4746835443037973}
# test 24 complete
#
# best accuracy on cv set was 0.8266199649737302
# acc on training set is 0.8441330998248686
# accuracy on validation set was 0.8111888111888111
# f1_score for validation set is 0.7567567567567567
# precision score for validation set is 0.8571428571428571
# recall score for validation set is 0.6774193548387096
# best_params_ are {'kernel': 'rbf', 'gamma': 0.03050632911392405, 'coef0': 1.89873417721519, 'C': 1.4873417721518987}
# test 25 complete
#
# best accuracy on cv set was 0.8161120840630472
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.8881118881118881
# f1_score for validation set is 0.8571428571428571
# precision score for validation set is 0.9411764705882353
# recall score for validation set is 0.7868852459016393
# best_params_ are {'kernel': 'rbf', 'gamma': 0.012658227848101266, 'coef0': 4.556962025316456, 'C': 18.27215189873418}
# test 26 complete
#
# best accuracy on cv set was 0.830122591943958
# acc on training set is 0.8669001751313485
# accuracy on validation set was 0.8251748251748252
# f1_score for validation set is 0.761904761904762
# precision score for validation set is 0.851063829787234
# recall score for validation set is 0.6896551724137931
# best_params_ are {'kernel': 'rbf', 'gamma': 0.024050632911392405, 'coef0': 7.848101265822786, 'C': 5.189873417721519}
# test 27 complete
#
# best accuracy on cv set was 0.819614711033275
# acc on training set is 0.8581436077057794
# accuracy on validation set was 0.8041958041958042
# f1_score for validation set is 0.7307692307692307
# precision score for validation set is 0.8444444444444444
# recall score for validation set is 0.6440677966101694
# best_params_ are {'kernel': 'rbf', 'gamma': 0.014177215189873419, 'coef0': 2.9113924050632916, 'C': 14.569620253164558}
# test 28 complete
#
# best accuracy on cv set was 0.8353765323992994
# acc on training set is 0.8528896672504378
# accuracy on validation set was 0.8111888111888111
# f1_score for validation set is 0.7326732673267328
# precision score for validation set is 0.7872340425531915
# recall score for validation set is 0.6851851851851852
# best_params_ are {'kernel': 'rbf', 'gamma': 0.026329113924050636, 'coef0': 3.1645569620253164, 'C': 2.4746835443037973}
# test 29 complete
#
# average training accuracy was 0.8239346176298891
# average validation accuracy was 0.825174825174825
# <div id="7369a0a1-42cd-41dd-b256-d017a1e34be2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '7369a0a1-42cd-41dd-b256-d017a1e34be2',
#             [{"name": "train", "opacity": 0.5, "x": [0.8318739054290718, 0.8073555166374781, 0.8231173380035026, 0.8423817863397548, 0.8178633975481612, 0.8231173380035026, 0.8248686514886164, 0.8213660245183888, 0.819614711033275, 0.8266199649737302, 0.8336252189141856, 0.8213660245183888, 0.8178633975481612, 0.840630472854641, 0.830122591943958, 0.8108581436077058, 0.8231173380035026, 0.819614711033275, 0.8108581436077058, 0.8161120840630472, 0.8231173380035026, 0.8371278458844134, 0.8161120840630472, 0.8266199649737302, 0.8248686514886164, 0.8266199649737302, 0.8161120840630472, 0.830122591943958, 0.819614711033275, 0.8353765323992994], "type": "histogram", "uid": "7ac373ac-a5b7-11e8-b902-88e9fe7b2dc1"}, {"name": "valid", "opacity": 0.5, "x": [0.7972027972027972, 0.8461538461538461, 0.8251748251748252, 0.7622377622377622, 0.8041958041958042, 0.8321678321678322, 0.8531468531468531, 0.8391608391608392, 0.8461538461538461, 0.8111888111888111, 0.7972027972027972, 0.8251748251748252, 0.8251748251748252, 0.7552447552447552, 0.7972027972027972, 0.8881118881118881, 0.8181818181818182, 0.8601398601398601, 0.8321678321678322, 0.8461538461538461, 0.8111888111888111, 0.7972027972027972, 0.8531468531468531, 0.8321678321678322, 0.8601398601398601, 0.8111888111888111, 0.8881118881118881, 0.8251748251748252, 0.8041958041958042, 0.8111888111888111], "type": "histogram", "uid": "7ac377c6-a5b7-11e8-b902-88e9fe7b2dc1"}],
#             {"barmode": "stack"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('7369a0a1-42cd-41dd-b256-d017a1e34be2',{});}).then(function(){Plotly.animate('7369a0a1-42cd-41dd-b256-d017a1e34be2');})
#         });</script>

# %%
save_best_params = True

if save_best_params:
    pkl.dump(best_params, open('svc_best_params.pkl', 'wb'))

# %%
for param in param_opt_dict:
    x = []
    y = []
    param_opt_list = param_opt_dict[param]
    for (xs, ys) in param_opt_list:
        x.append(xs)
        y.append(ys)

    print(param)

    py.iplot([go.Scatter(x=x, y=y, mode='markers')])
# Out:
# C
# <div id="f68cadcb-1673-4df9-a3ca-23d13ee9e9d6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f68cadcb-1673-4df9-a3ca-23d13ee9e9d6", [{"mode": "markers", "x": [19.753164556962027, 4.69620253164557, 2.7215189873417724, 6.424050632911393, 7.4113924050632916, 1.7341772151898736, 4.69620253164557, 8.645569620253164, 14.075949367088608, 18.025316455696203, 0.7468354430379747, 11.854430379746836, 2.968354430379747, 13.58227848101266, 1.240506329113924, 8.645569620253164, 18.518987341772153, 0.5, 11.113924050632912, 18.518987341772153, 0.5, 3.708860759493671, 4.449367088607595, 6.177215189873418, 8.151898734177216, 16.29746835443038, 3.2151898734177218, 20.0, 15.310126582278482, 7.4113924050632916], "y": [0.6666666666666666, 0.47619047619047616, 0.5714285714285714, 0.5714285714285714, 0.6190476190476191, 0.6666666666666666, 0.7142857142857143, 0.6666666666666666, 0.6190476190476191, 0.5714285714285714, 0.47619047619047616, 0.42857142857142855, 0.7619047619047619, 0.6190476190476191, 0.47619047619047616, 0.5714285714285714, 0.5238095238095238, 0.3333333333333333, 0.6190476190476191, 0.6666666666666666, 0.5714285714285714, 0.8571428571428571, 0.6190476190476191, 0.5714285714285714, 0.38095238095238093, 0.7619047619047619, 0.6666666666666666, 0.5714285714285714, 0.7619047619047619, 0.6666666666666666], "type": "scatter", "uid": "42187ce2-a368-11e8-8e34-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# kernel
# <div id="f941248e-dae8-4abc-84e4-a987a2cb0781" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f941248e-dae8-4abc-84e4-a987a2cb0781", [{"mode": "markers", "x": ["rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf", "rbf"], "y": [0.6666666666666666, 0.47619047619047616, 0.5714285714285714, 0.5714285714285714, 0.6190476190476191, 0.6666666666666666, 0.7142857142857143, 0.6666666666666666, 0.6190476190476191, 0.5714285714285714, 0.47619047619047616, 0.42857142857142855, 0.7619047619047619, 0.6190476190476191, 0.47619047619047616, 0.5714285714285714, 0.5238095238095238, 0.3333333333333333, 0.6190476190476191, 0.6666666666666666, 0.5714285714285714, 0.8571428571428571, 0.6190476190476191, 0.5714285714285714, 0.38095238095238093, 0.7619047619047619, 0.6666666666666666, 0.5714285714285714, 0.7619047619047619, 0.6666666666666666], "type": "scatter", "uid": "4222b482-a368-11e8-8e34-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# gamma
# <div id="03b01088-2c0f-4123-87a5-ccb43580cad4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03b01088-2c0f-4123-87a5-ccb43580cad4", [{"mode": "markers", "x": [0.019113924050632912, 0.014177215189873419, 0.01189873417721519, 0.01607594936708861, 0.026329113924050636, 0.015316455696202533, 0.019113924050632912, 0.036582278481012656, 0.03582278481012658, 0.02518987341772152, 0.02518987341772152, 0.03164556962025317, 0.03848101265822785, 0.03734177215189873, 0.0369620253164557, 0.01, 0.038860759493670884, 0.012658227848101266, 0.011518987341772152, 0.016455696202531647, 0.010379746835443038, 0.02670886075949367, 0.022531645569620253, 0.01379746835443038, 0.03848101265822785, 0.011518987341772152, 0.03316455696202532, 0.02518987341772152, 0.010379746835443038, 0.0369620253164557], "y": [0.6666666666666666, 0.47619047619047616, 0.5714285714285714, 0.5714285714285714, 0.6190476190476191, 0.6666666666666666, 0.7142857142857143, 0.6666666666666666, 0.6190476190476191, 0.5714285714285714, 0.47619047619047616, 0.42857142857142855, 0.7619047619047619, 0.6190476190476191, 0.47619047619047616, 0.5714285714285714, 0.5238095238095238, 0.3333333333333333, 0.6190476190476191, 0.6666666666666666, 0.5714285714285714, 0.8571428571428571, 0.6190476190476191, 0.5714285714285714, 0.38095238095238093, 0.7619047619047619, 0.6666666666666666, 0.5714285714285714, 0.7619047619047619, 0.6666666666666666], "type": "scatter", "uid": "422a578c-a368-11e8-8e34-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# coef0
# <div id="671d297c-edd8-43b4-8181-a41df37cb4b9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("671d297c-edd8-43b4-8181-a41df37cb4b9", [{"mode": "markers", "x": [3.670886075949367, 8.734177215189874, 6.835443037974684, 8.734177215189874, 5.69620253164557, 2.6582278481012658, 7.974683544303798, 6.962025316455697, 4.4303797468354436, 3.79746835443038, 0.6329113924050633, 6.962025316455697, 3.1645569620253164, 0.25316455696202533, 2.405063291139241, 2.278481012658228, 5.822784810126583, 7.088607594936709, 9.113924050632912, 0.12658227848101267, 7.088607594936709, 0.12658227848101267, 3.5443037974683547, 6.455696202531646, 0.379746835443038, 7.215189873417722, 3.79746835443038, 1.518987341772152, 2.9113924050632916, 8.481012658227849], "y": [0.6666666666666666, 0.47619047619047616, 0.5714285714285714, 0.5714285714285714, 0.6190476190476191, 0.6666666666666666, 0.7142857142857143, 0.6666666666666666, 0.6190476190476191, 0.5714285714285714, 0.47619047619047616, 0.42857142857142855, 0.7619047619047619, 0.6190476190476191, 0.47619047619047616, 0.5714285714285714, 0.5238095238095238, 0.3333333333333333, 0.6190476190476191, 0.6666666666666666, 0.5714285714285714, 0.8571428571428571, 0.6190476190476191, 0.5714285714285714, 0.38095238095238093, 0.7619047619047619, 0.6666666666666666, 0.5714285714285714, 0.7619047619047619, 0.6666666666666666], "type": "scatter", "uid": "42324f1e-a368-11e8-8e34-88e9fe7b2dc1"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
